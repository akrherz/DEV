# %%
from pandas.io.sql import read_sql
from pyiem.network import Table as NetworkTable
from pyiem.plot import MapPlot
from pyiem.database import get_dbconn

networks = ["IA_ASOS", "AWOS"]
nt = NetworkTable(networks)
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
ASOS = get_dbconn("iem")
df = read_sql(
    """
  select max(day), id, network, name, st_x(geom) as lon, st_y(geom) as lat from summary s JOIN stations t on (t.iemid = s.iemid) WHERE
  t.network in ('IA_ASOS','AWOS') and max_dwpf >= 79.5 GROUP by id, network, name, lon, lat ORDER by id 
""",
    ASOS,
    index_col="id",
)
#    vals.append( row[0].strftime("%-m/%-d\n%Y" if row[0].year != 2014 else "%-m/%-d") )

# %%
df.sort_values("max", inplace=True)
df.reset_index(inplace=True)
df["labels"] = df.apply(
    lambda x: "%s\n%s"
    % (
        x["name"],
        x["max"].strftime(
            "%-m/%-d/%Y" if x["max"].year != 2016 else "%-m/%-d"
        ),
    ),
    axis=1,
)
print(df)
# Out:
#      id         max  network             name        lon        lat  \
# 0   DSM  2010-08-10  IA_ASOS       DES MOINES -93.653114  41.533950
# 1   IIB  2011-06-13     AWOS     INDEPENDENCE -91.950400  42.454428
# 2   DEH  2011-07-19     AWOS          DECORAH -91.743314  43.275519
# 3   ALO  2011-07-27  IA_ASOS         Waterloo -92.401293  42.554365
# 4   GGI  2011-08-01     AWOS         Grinnell -92.733197  41.709731
# 5   SUX  2011-08-01  IA_ASOS       SIOUX CITY -96.379478  42.391678
# 6   SPW  2011-08-01  IA_ASOS          SPENCER -95.210088  43.168218
# 7   ORC  2011-08-01     AWOS      Orange City -96.060586  42.989492
# 8   MCW  2011-08-01  IA_ASOS       MASON CITY -93.326097  43.154383
# 9   DBQ  2011-08-02  IA_ASOS          DUBUQUE -90.709143  42.398350
# 10  OXV  2011-08-06     AWOS        Knoxville -93.111392  41.298447
# 11  CAV  2012-07-23     AWOS          CLARION -93.759258  42.743042
# 12  FXY  2014-03-27     AWOS      Forest City -93.623669  43.232317
# 13  EBS  2014-07-06     AWOS     Webster City -93.869078  42.439231
# 14  OLZ  2014-07-07     AWOS          OELWEIN -91.975989  42.683139
# 15  IOW  2014-07-22  IA_ASOS        IOWA CITY -91.544535  41.639390
# 16  IKV  2015-07-12     AWOS           ANKENY -93.569475  41.687808
# 17  VTI  2015-07-12     AWOS           VINTON -92.024842  42.217578
# 18  DVN  2015-07-13  IA_ASOS      QUAD CITIES -90.594829  41.613329
# 19  FFL  2015-07-13     AWOS        FAIRFIELD -91.983411  41.052089
# 20  MXO  2015-07-13     AWOS  MONTICELLO MUNI -91.160456  42.220361
# 21  CWI  2015-07-13     AWOS          CLINTON -90.332796  41.829504
# 22  SLB  2015-07-17     AWOS       Storm Lake -95.239919  42.597228
# 23  CNC  2015-07-17     AWOS         CHARITON -93.360769  41.018431
# 24  LRJ  2015-07-17     AWOS          LE MARS -96.192250  42.775375
# 5         SIOUX CITY\n8/1/2011
# 6            SPENCER\n8/1/2011
# 7        Orange City\n8/1/2011
# 8         MASON CITY\n8/1/2011
# 9            DUBUQUE\n8/2/2011
# 10         Knoxville\n8/6/2011
# 11          CLARION\n7/23/2012
# 12      Forest City\n3/27/2014
# 13      Webster City\n7/6/2014
# 14           OELWEIN\n7/7/2014
# 15        IOWA CITY\n7/22/2014
# 16           ANKENY\n7/12/2015
# 17           VINTON\n7/12/2015
# 18      QUAD CITIES\n7/13/2015
# 19        FAIRFIELD\n7/13/2015
# 20  MONTICELLO MUNI\n7/13/2015
# 21          CLINTON\n7/13/2015
# 22       Storm Lake\n7/17/2015
# 23         CHARITON\n7/17/2015
# 24          LE MARS\n7/17/2015
# 25     CEDAR RAPIDS\n7/17/2015
# 26          AUDUBON\n7/28/2015
# 27      KEOKUK MUNI\n7/28/2015
# 28          OTTUMWA\n7/28/2015
# 29     FORT MADISON\n7/28/2015
# 30      Centerville\n7/28/2015
# 31            PELLA\n9/17/2015
# 32         COUNCIL BLUFFS\n7/5
# 33                CRESTON\n7/5
# 34                 LAMONI\n7/5
# 35                Osceola\n7/5
# 36                DENISON\n7/5
# 37             MUSCATINE\n7/17
# 38           NEWTON MUNI\n7/20
# 39              ATLANTIC\n7/20
# 40                  Ames\n7/20
# 41               SHELDON\n7/20
# 42       SHENANDOAH MUNI\n7/20
# 43               RED OAK\n7/20
# 44                 Perry\n7/20
# 45              Cherokee\n7/20
# 46            WASHINGTON\n7/20
# 47              CLARINDA\n7/20
# 48            Iowa Falls\n7/20
# 49             Oskaloosa\n7/20
# 50            BOONE MUNI\n7/20
# 51            FORT DODGE\n7/20
# 52        MOUNT PLEASANT\n7/20
# 53          MARSHALLTOWN\n7/20
# 54            BURLINGTON\n7/20
# 55               CARROLL\n7/20
# 56                HARLAN\n7/20
# 57          CHARLES CITY\n7/20
# 58           ESTHERVILLE\n7/20
# 59                ALGONA\n7/20

# %%
m = MapPlot(
    sector="iowa",
    axisbg="white",
    title="Date of Last 80+$^\circ$F Dew Point Temperature Observation (Iowa ASOS Sites)",
    subtitle="thru 20 July 2016, dates without year are 2016 days, based on hourly obs",
)

df2 = df[df["network"] == "IA_ASOS"]
m.plot_values(df2["lon"], df2["lat"], df2["labels"], "%s", labelbuffer=1)
# m.contourf(lons, lats, vals, np.arange(750,2051,100), units='total change in mb')
# m.drawcounties()
m.postprocess(filename="160721.png")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 m = MapPlot(
#       2     sector="iowa",
#       3     axisbg="white",
#       4     title="Date of Last 80+$^\circ$F Dew Point Temperature Observation (Iowa ASOS Sites)",
#       5     subtitle="thru 20 July 2016, dates without year are 2016 days, based on hourly obs",
#       6 )
#       8 df2 = df[df["network"] == "IA_ASOS"]
#       9 m.plot_values(df2["lon"], df2["lat"], df2["labels"], "%s", labelbuffer=1)
#
# NameError: name 'MapPlot' is not defined
