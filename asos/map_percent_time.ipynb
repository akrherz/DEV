# %%
import pandas as pd
from pyiem.network import Table as NetworkTable
from pyiem.util import get_dbconn

# sts = datetime.datetime(2013,12,1)
# ets = datetime.datetime(2014,2,26,8)
# total = (ets - sts).days * 86400. + (ets - sts).seconds
total = 2015 - 1973
ASOS = get_dbconn("asos")
acursor = ASOS.cursor()

MESOSITE = get_dbconn("mesosite")
mcursor = MESOSITE.cursor()

networks = [
    "AWOS",
]
mcursor.execute("""SELECT distinct network from stations where country = 'US' and 
 network ~* 'ASOS'""")
for row in mcursor:
    networks.append(row[0])

# nt = network.Table(('IA_ASOS','MO_ASOS','IL_ASOS', 'ND_ASOS', 'AWOS',
#          'WI_ASOS','MN_ASOS', 'SD_ASOS', 'NE_ASOS', 'KS_ASOS',
#          'IN_ASOS','KY_ASOS','OH_ASOS','MI_ASOS'))
nt = NetworkTable(networks)
rows = []
for sid in nt.sts.keys():
    if (
        nt.sts[sid]["archive_begin"] is None
        or nt.sts[sid]["archive_begin"].year > 1973
    ):
        continue

    # Figure out what our archive coverage is, 41 years would be perfect
    acursor.execute(
        """
    select yr from 
        (SELECT substring(d, 1, 4) as yr, count(*) from 
            (select distinct to_char(valid, 'YYYYmmddHH24') as d from alldata 
            where station = %s and valid > '1973-01-01' and valid < '2015-01-01') as foo 
        GROUP by yr) as foo2 
    WHERE count > (365. * 24 * .9)
    """,
        (sid,),
    )
    if acursor.rowcount < 37:
        print(
            "Skipping %s, due to only have %s/41 years of data"
            % (sid, acursor.rowcount)
        )
        continue

    acursor.execute(
        """
  with delta as (select valid, tmpf - lag(tmpf) OVER (ORDER by valid ASC) as deleta 
  from alldata where station = %s and tmpf is not null and valid > '1973-01-01'), 
  
  cnts as (select date(valid at time zone %s)  as d, sum(case when deleta > 0 then 1 else 0 end), 
  count(*) from delta GROUP by d) 
  
  SELECT count(*) from cnts where count > 20 and sum = 0
""",
        (sid, nt.sts[sid]["tzname"]),
    )

    row = acursor.fetchone()
    rows.append(
        dict(
            sid=sid,
            lat=nt.sts[sid]["lat"],
            lon=nt.sts[sid]["lon"],
            val=row[0],
            network=nt.sts[sid]["network"],
        )
    )
    print(sid, row[0] / float(total) * 100.0, row[0])

df = pd.DataFrame(rows)
# Out:
# Populating the interactive namespace from numpy and matplotlib
# AGC 90.4761904762 38
# Skipping NYC, due to only have 15/41 years of data
# AGS 28.5714285714 12
# Skipping NYG, due to only have 26/41 years of data
# Skipping PHMK, due to only have 24/41 years of data
# PKB 76.1904761905 32
# SPS 16.6666666667 7
# SPI 73.8095238095 31
# Skipping BWD, due to only have 12/41 years of data
# BWG 42.8571428571 18
# BWI 30.9523809524 13
# Skipping PADK, due to only have 31/41 years of data
# Skipping PADL, due to only have 29/41 years of data
# Skipping IXD, due to only have 16/41 years of data
# PADQ 78.5714285714 33
# Skipping PADU, due to only have 21/41 years of data
# Skipping BYH, due to only have 19/41 years of data
# Skipping BYI, due to only have 33/41 years of data
# Skipping JNW, due to only have 0/41 years of data
# Skipping SNA, due to only have 15/41 years of data
# Skipping PQI, due to only have 20/41 years of data
# Skipping B23, due to only have 0/41 years of data
# SNS 0.0 0
# MAF 16.6666666667 7
# Skipping MAI, due to only have 4/41 years of data
# Skipping BEH, due to only have 16/41 years of data
# Skipping BED, due to only have 15/41 years of data
# Skipping BJI, due to only have 22/41 years of data
# Skipping MLD, due to only have 0/41 years of data
# EVV 85.7142857143 36
# Skipping EVW, due to only have 19/41 years of data
# LSF 42.8571428571 18
# LSE 69.0476190476 29
# LSV 4.7619047619 2
# Skipping TTN, due to only have 16/41 years of data
# Skipping TTD, due to only have 18/41 years of data
# GRR 102.380952381 43
# GRF 26.1904761905 11
# GRB 35.7142857143 15
# GRK 78.5714285714 33
# GRI 69.0476190476 29
# Skipping NOG, due to only have 27/41 years of data
# Skipping HLR, due to only have 11/41 years of data
# HLN 19.0476190476 8
# Skipping HLG, due to only have 23/41 years of data
# Skipping HLC, due to only have 17/41 years of data
# Skipping VBG, due to only have 10/41 years of data
# Skipping CTY, due to only have 27/41 years of data
# MKG 107.142857143 45
# Skipping CTB, due to only have 13/41 years of data
# Skipping 79J, due to only have 8/41 years of data
# Skipping SPA, due to only have 5/41 years of data
# Skipping EDE, due to only have 15/41 years of data
# LMT 2.38095238095 1
# Skipping ORL, due to only have 35/41 years of data
# Skipping EDW, due to only have 17/41 years of data
# Skipping ORH, due to only have 35/41 years of data
# ORF 35.7142857143 15
# ORD 59.5238095238 25
# Skipping DPG, due to only have 0/41 years of data
# Skipping FHU, due to only have 8/41 years of data
# Skipping UKI, due to only have 30/41 years of data
# Skipping ONO, due to only have 16/41 years of data
# Skipping ONL, due to only have 12/41 years of data
# Skipping ONM, due to only have 4/41 years of data
# IGM 14.2857142857 6
# Skipping ONP, due to only have 13/41 years of data
# ONT 0.0 0
# PNS 4.7619047619 2
# Skipping PNC, due to only have 34/41 years of data
# Skipping PNE, due to only have 36/41 years of data
# PAKN 59.5238095238 25
# Skipping PAKT, due to only have 35/41 years of data
# SAN 4.7619047619 2
# PRC 0.0 0
# PRB 0.0 0
# SAC 0.0 0
# Skipping SAF, due to only have 20/41 years of data
# Skipping SAD, due to only have 16/41 years of data
# Skipping SAW, due to only have 35/41 years of data
# SAV 19.0476190476 8
# SAT 28.5714285714 12
# CHA 23.8095238095 10
# JAX 11.9047619048 5
# Skipping CHO, due to only have 12/41 years of data
# JAN 50.0 21
# CHS 19.0476190476 8
# Skipping MRF, due to only have 29/41 years of data
# Skipping JAC, due to only have 19/41 years of data
# MRB 35.7142857143 15
# MRC 80.9523809524 34
# APN 80.9523809524 34
# Skipping DBQ, due to only have 32/41 years of data
# Skipping APC, due to only have 16/41 years of data
# ISN 33.3333333333 14
# Skipping NPA, due to only have 35/41 years of data
# Skipping NLC, due to only have 33/41 years of data
# Skipping ATY, due to only have 26/41 years of data
# GCK 16.6666666667 7
# DLH 142.857142857 60
# Skipping DLN, due to only have 16/41 years of data
# Skipping DLS, due to only have 11/41 years of data
# PAYA 28.5714285714 12
# BTV 104.761904762 44
# BTR 28.5714285714 12
# Skipping PHNG, due to only have 32/41 years of data
# Skipping SSI, due to only have 36/41 years of data
# Skipping NUW, due to only have 34/41 years of data
# Skipping BTM, due to only have 23/41 years of data
# Skipping BTL, due to only have 24/41 years of data
# PHNL 2.38095238095 1
# SSC 35.7142857143 15
# DHN 26.1904761905 11
# Skipping WYS, due to only have 1/41 years of data
# Skipping ECG, due to only have 16/41 years of data
# Skipping JKL, due to only have 34/41 years of data
# Skipping SEE, due to only have 4/41 years of data
# Skipping LNS, due to only have 15/41 years of data
# Skipping LNR, due to only have 13/41 years of data
# Skipping LNN, due to only have 0/41 years of data
# Skipping RMG, due to only have 4/41 years of data
# LNK 45.2380952381 19
# LND 11.9047619048 5
# EUG 4.7619047619 2
# Skipping PAFB, due to only have 2/41 years of data
# Skipping BBW, due to only have 14/41 years of data
# Skipping TUP, due to only have 32/41 years of data
# TUS 0.0 0
# TUL 40.4761904762 17
# CYS 28.5714285714 12
# FYV 38.0952380952 16
# Skipping POE, due to only have 30/41 years of data
# POB 52.380952381 22
# Skipping FKL, due to only have 21/41 years of data
# VCT 16.6666666667 7
# Skipping VCV, due to only have 20/41 years of data
# Skipping CWA, due to only have 15/41 years of data
# Skipping CWF, due to only have 4/41 years of data
# Skipping SNY, due to only have 30/41 years of data
# Skipping CKB, due to only have 18/41 years of data
# VLD 14.2857142857 6
# Skipping SLK, due to only have 15/41 years of data
# Skipping PAH, due to only have 34/41 years of data
# PAM 14.2857142857 6
# DCA 16.6666666667 7
# FWA 102.380952381 43
# Skipping WEY, due to only have 0/41 years of data
# Skipping OIN, due to only have 12/41 years of data
# Skipping AEX, due to only have 25/41 years of data
# Skipping DMN, due to only have 22/41 years of data
# BUR 2.38095238095 1
# Skipping BUO, due to only have 0/41 years of data
# Skipping PHOG, due to only have 35/41 years of data
# BUF 97.619047619 41
# PAJN 50.0 21
# Skipping INW, due to only have 35/41 years of data
# Skipping PFYU, due to only have 26/41 years of data
# Skipping PSK, due to only have 17/41 years of data
# PSM 78.5714285714 33
# Skipping PSF, due to only have 12/41 years of data
# MOT 69.0476190476 29
# Skipping PSX, due to only have 33/41 years of data
# PIA 88.0952380952 37
# MOB 35.7142857143 15
# Skipping PSP, due to only have 16/41 years of data
# JLN 66.6666666667 28
# Skipping MOD, due to only have 15/41 years of data
# Skipping BCE, due to only have 14/41 years of data
# PIE 9.52380952381 4
# VRB 0.0 0
# Skipping TVF, due to only have 22/41 years of data
# TVC 90.4761904762 38
# Skipping SRN, due to only have 1/41 years of data
# Skipping SRQ, due to only have 15/41 years of data
# Skipping TDO, due to only have 0/41 years of data
# Skipping TDZ, due to only have 16/41 years of data
# Skipping PTK, due to only have 15/41 years of data
# Skipping NMM, due to only have 33/41 years of data
# Skipping CVS, due to only have 34/41 years of data
# Skipping LOL, due to only have 33/41 years of data
# Skipping CVO, due to only have 20/41 years of data
# CVH 0.0 0
# LOU 52.380952381 22
# Skipping LOZ, due to only have 31/41 years of data
# CVG 121.428571429 51
# BIL 45.2380952381 19
# ELM 47.619047619 20
# HPN 35.7142857143 15
# Skipping BIE, due to only have 16/41 years of data
# Skipping DRT, due to only have 29/41 years of data
# Skipping DRO, due to only have 17/41 years of data
# Skipping IOW, due to only have 18/41 years of data
# UIL 30.9523809524 13
# UIN 88.0952380952 37
# ABY 14.2857142857 6
# Skipping CXY, due to only have 33/41 years of data
# Skipping CXL, due to only have 30/41 years of data
# Skipping PAIL, due to only have 21/41 years of data
# Skipping PAIM, due to only have 11/41 years of data
# SCK 0.0 0
# Skipping JMS, due to only have 34/41 years of data
# Skipping MNM, due to only have 20/41 years of data
# Skipping PBG, due to only have 29/41 years of data
# Skipping PBF, due to only have 26/41 years of data
# PBI 0.0 0
# Skipping AVX, due to only have 14/41 years of data
# MLS 35.7142857143 15
# AVP 66.6666666667 28
# AVL 33.3333333333 14
# Skipping SUN, due to only have 8/41 years of data
# MLU 40.4761904762 17
# SUU 0.0 0
# Skipping SUS, due to only have 33/41 years of data
# SUX 88.0952380952 37
# TEB 28.5714285714 12
# NBC 7.14285714286 3
# SLC 2.38095238095 1
# Skipping NBG, due to only have 34/41 years of data
# Skipping ADM, due to only have 8/41 years of data
# Skipping MWC, due to only have 7/41 years of data
# MCI 88.0952380952 37
# Skipping BRX, due to only have 2/41 years of data
# BRO 35.7142857143 15
# BRL 69.0476190476 29
# Skipping BRD, due to only have 10/41 years of data
# Skipping TWF, due to only have 16/41 years of data
# Skipping U31, due to only have 0/41 years of data
# Skipping HQM, due to only have 14/41 years of data
# Skipping MWH, due to only have 16/41 years of data
# RKS 19.0476190476 8
# SEA 14.2857142857 6
# Skipping EAR, due to only have 15/41 years of data
# EAU 54.7619047619 23
# EAT 19.0476190476 8
# Skipping HOB, due to only have 7/41 years of data
# HON 61.9047619048 26
# Skipping ESF, due to only have 23/41 years of data
# Skipping HOT, due to only have 14/41 years of data
# HOU 23.8095238095 10
# Skipping ESC, due to only have 20/41 years of data
# HOP 100.0 42
# Skipping KLS, due to only have 21/41 years of data
# Skipping SCH, due to only have 0/41 years of data
# YIP 40.4761904762 17
# Skipping GON, due to only have 14/41 years of data
# Skipping FIR, due to only have 2/41 years of data
# Skipping FIT, due to only have 16/41 years of data
# Skipping VAD, due to only have 33/41 years of data
# Skipping LHW, due to only have 9/41 years of data
# Skipping LHX, due to only have 27/41 years of data
# CMH 66.6666666667 28
# Skipping CMA, due to only have 22/41 years of data
# Skipping DSV, due to only have 14/41 years of data
# DSM 107.142857143 45
# Skipping RWF, due to only have 35/41 years of data
# Skipping INT, due to only have 32/41 years of data
# Skipping RWI, due to only have 16/41 years of data
# Skipping RWL, due to only have 22/41 years of data
# Skipping INS, due to only have 4/41 years of data
# INL 85.7142857143 36
# OKC 26.1904761905 11
# Skipping INK, due to only have 34/41 years of data
# IND 97.619047619 41
# Skipping GLH, due to only have 13/41 years of data
# Skipping AKR, due to only have 13/41 years of data
# GLD 21.4285714286 9
# Skipping CJR, due to only have 15/41 years of data
# Skipping AKO, due to only have 32/41 years of data
# Skipping GLS, due to only have 33/41 years of data
# DOV 38.0952380952 16
# AUG 47.619047619 20
# Skipping PAHZ, due to only have 0/41 years of data
# PAHO 14.2857142857 6
# Skipping PAHN, due to only have 15/41 years of data
# Skipping MMT, due to only have 8/41 years of data
# SBY 47.619047619 20
# Skipping PUB, due to only have 36/41 years of data
# Skipping PUC, due to only have 23/41 years of data
# Skipping SBD, due to only have 20/41 years of data
# Skipping PUW, due to only have 15/41 years of data
# SBN 80.9523809524 34
# Skipping ERV, due to only have 12/41 years of data
# Skipping BAF, due to only have 15/41 years of data
# Skipping BAD, due to only have 35/41 years of data
# LCK 73.8095238095 31
# Skipping BAB, due to only have 31/41 years of data
# Skipping BAK, due to only have 0/41 years of data
# Skipping MPV, due to only have 36/41 years of data
# VPS 26.1904761905 11
# Skipping STC, due to only have 32/41 years of data
# STL 80.9523809524 34
# Skipping BNW, due to only have 15/41 years of data
# Skipping STJ, due to only have 19/41 years of data
# Skipping STK, due to only have 32/41 years of data
# Skipping STS, due to only have 15/41 years of data
# Skipping JXN, due to only have 34/41 years of data
# FNT 142.857142857 60
# Skipping LIC, due to only have 18/41 years of data
# LIT 45.2380952381 19
# Skipping PGV, due to only have 17/41 years of data
# Skipping ACK, due to only have 19/41 years of data
# TPA 14.2857142857 6
# Skipping HRT, due to only have 30/41 years of data
# Skipping TPL, due to only have 21/41 years of data
# Skipping TPH, due to only have 33/41 years of data
# Skipping HRL, due to only have 17/41 years of data
# Skipping HRO, due to only have 34/41 years of data
# Skipping HDO, due to only have 25/41 years of data
# Skipping RHI, due to only have 15/41 years of data
# Skipping RTN, due to only have 15/41 years of data
# Skipping HFD, due to only have 18/41 years of data
# Skipping OJC, due to only have 17/41 years of data
# Skipping END, due to only have 32/41 years of data
# Skipping OXR, due to only have 16/41 years of data
# Skipping ENV, due to only have 30/41 years of data
# RFD 83.3333333333 35
# NIP 4.7619047619 2
# Skipping CZZ, due to only have 16/41 years of data
# Skipping CZK, due to only have 0/41 years of data
# Skipping CZD, due to only have 12/41 years of data
# Skipping PAOR, due to only have 34/41 years of data
# PAOT 66.6666666667 28
# ATL 40.4761904762 17
# ISP 42.8571428571 18
# ATT 40.4761904762 17
# Skipping ISO, due to only have 9/41 years of data
# PAOM 45.2380952381 19
# Skipping PVW, due to only have 11/41 years of data
# Skipping SEG, due to only have 16/41 years of data
# PVD 23.8095238095 10
# Skipping FDK, due to only have 12/41 years of data
# Skipping CLL, due to only have 36/41 years of data
# Skipping 3DU, due to only have 0/41 years of data
# PDX 2.38095238095 1
# CLE 116.666666667 49
# Skipping FRI, due to only have 26/41 years of data
# PDT 7.14285714286 3
# Skipping IML, due to only have 10/41 years of data
# Skipping FRM, due to only have 21/41 years of data
# Skipping IMT, due to only have 15/41 years of data
# CLT 45.2380952381 19
# Skipping SWO, due to only have 17/41 years of data
# Skipping BPI, due to only have 36/41 years of data
# Skipping SWF, due to only have 12/41 years of data
# BPT 38.0952380952 16
# Skipping PAE, due to only have 15/41 years of data
# Skipping GYH, due to only have 5/41 years of data
# Skipping GYR, due to only have 0/41 years of data
# MLB 9.52380952381 4
# MLC 54.7619047619 23
# Skipping MLF, due to only have 24/41 years of data
# MLI 102.380952381 43
# Skipping MLP, due to only have 17/41 years of data
# Skipping MLT, due to only have 18/41 years of data
# Skipping DHT, due to only have 33/41 years of data
# Skipping NRN, due to only have 12/41 years of data
# Skipping NRB, due to only have 21/41 years of data
# Skipping PHBK, due to only have 7/41 years of data
# Skipping NRS, due to only have 5/41 years of data
# HSE 38.0952380952 16
# RIV 0.0 0
# Skipping RIW, due to only have 18/41 years of data
# Skipping HSI, due to only have 14/41 years of data
# HSV 40.4761904762 17
# Skipping GMU, due to only have 14/41 years of data
# HST 0.0 0
# RIC 21.4285714286 9
# Skipping PASC, due to only have 33/41 years of data
# Skipping PASN, due to only have 30/41 years of data
# Skipping PASI, due to only have 35/41 years of data
# Skipping PASV, due to only have 11/41 years of data
# Skipping PASW, due to only have 0/41 years of data
# Skipping BNO, due to only have 32/41 years of data
# BNA 76.1904761905 32
# Skipping PASY, due to only have 27/41 years of data
# Skipping LXV, due to only have 15/41 years of data
# Skipping SYF, due to only have 32/41 years of data
# SYR 83.3333333333 35
# Skipping NTD, due to only have 29/41 years of data
# Skipping 1V4, due to only have 17/41 years of data
# Skipping LXN, due to only have 12/41 years of data
# Skipping EMP, due to only have 21/41 years of data
# Skipping MER, due to only have 24/41 years of data
# Skipping FOE, due to only have 31/41 years of data
# Skipping FOK, due to only have 14/41 years of data
# ILG 19.0476190476 8
# COS 16.6666666667 7
# Skipping ILE, due to only have 20/41 years of data
# Skipping ILN, due to only have 15/41 years of data
# Skipping FSI, due to only have 33/41 years of data
# ILM 16.6666666667 7
# Skipping COE, due to only have 21/41 years of data
# Skipping COD, due to only have 33/41 years of data
# Skipping COF, due to only have 9/41 years of data
# CON 16.6666666667 7
# PHX 0.0 0
# Skipping WAL, due to only have 17/41 years of data
# Skipping NQI, due to only have 34/41 years of data
# Skipping PRX, due to only have 18/41 years of data
# Skipping RUT, due to only have 21/41 years of data
# Skipping GNR, due to only have 22/41 years of data
# MKE 92.8571428571 39
# GNV 0.0 0
# Skipping GNT, due to only have 15/41 years of data
# Skipping DIK, due to only have 34/41 years of data
# Skipping MKO, due to only have 17/41 years of data
# MKL 40.4761904762 17
# Skipping AIO, due to only have 14/41 years of data
# Skipping MKT, due to only have 19/41 years of data
# Skipping JHW, due to only have 19/41 years of data
# Skipping AIA, due to only have 17/41 years of data
# Skipping NSI, due to only have 7/41 years of data
# Skipping NSE, due to only have 33/41 years of data
# Skipping PANT, due to only have 27/41 years of data
# PANC 45.2380952381 19
# Skipping IRK, due to only have 15/41 years of data
# Skipping PANI, due to only have 28/41 years of data
# Skipping PANN, due to only have 28/41 years of data
# Skipping PWT, due to only have 22/41 years of data
# Skipping SDY, due to only have 21/41 years of data
# Skipping T62, due to only have 0/41 years of data
# SDF 71.4285714286 30
# Skipping SDB, due to only have 30/41 years of data
# Skipping SDM, due to only have 17/41 years of data
# PWM 19.0476190476 8
# Skipping NAK, due to only have 12/41 years of data
# Skipping HBG, due to only have 14/41 years of data
# Skipping PARL, due to only have 3/41 years of data
# BOI 2.38095238095 1
# Skipping EPH, due to only have 14/41 years of data
# Skipping PARY, due to only have 32/41 years of data
# Skipping HBR, due to only have 35/41 years of data
# SXT 7.14285714286 3
# Skipping LYH, due to only have 30/41 years of data
# Skipping SVN, due to only have 35/41 years of data
# Skipping BQK, due to only have 16/41 years of data
# FSM 38.0952380952 16
# Skipping JVL, due to only have 11/41 years of data
# Skipping FLP, due to only have 16/41 years of data
# Skipping FLV, due to only have 36/41 years of data
# Skipping FLL, due to only have 32/41 years of data
# FLO 21.4285714286 9
# FLG 4.7619047619 2
# MCB 28.5714285714 12
# TRI 57.1428571429 24
# Skipping TRK, due to only have 12/41 years of data
# Skipping TRM, due to only have 33/41 years of data
# Skipping IKW, due to only have 36/41 years of data
# FSD 95.2380952381 40
# HTS 128.571428571 54
# Skipping HSP, due to only have 19/41 years of data
# Skipping ELN, due to only have 15/41 years of data
# RDR 142.857142857 60
# Skipping ELD, due to only have 32/41 years of data
# Skipping RDD, due to only have 26/41 years of data
# Skipping RDG, due to only have 20/41 years of data
# ELY 0.0 0
# RDM 11.9047619048 5
# ELP 0.0 0
# Skipping LEB, due to only have 34/41 years of data
# Skipping LEM, due to only have 12/41 years of data
# Skipping FBG, due to only have 35/41 years of data
# LEX 107.142857143 45
# NGP 19.0476190476 8
# PAMR 16.6666666667 7
# Skipping PAMH, due to only have 19/41 years of data
# Skipping PAPT, due to only have 0/41 years of data
# Skipping PAMD, due to only have 33/41 years of data
# PAMC 40.4761904762 17
# Skipping SGH, due to only have 7/41 years of data
# SGF 85.7142857143 36
# Skipping CNW, due to only have 0/41 years of data
# Skipping CNU, due to only have 24/41 years of data
# Skipping CNY, due to only have 15/41 years of data
# Skipping CNM, due to only have 36/41 years of data
# CNK 47.619047619 20
# ICT 42.8571428571 18
# Skipping DXR, due to only have 15/41 years of data
# Skipping PFN, due to only have 32/41 years of data
# Skipping PMDY, due to only have 9/41 years of data
# Skipping SIY, due to only have 17/41 years of data
# Skipping YUM, due to only have 30/41 years of data
# Skipping HMN, due to only have 32/41 years of data
# TAD 2.38095238095 1
# Skipping TAN, due to only have 14/41 years of data
# Skipping HMS, due to only have 9/41 years of data
# Skipping PACV, due to only have 35/41 years of data
# CDC 0.0 0
# AHN 45.2380952381 19
# Skipping PACZ, due to only have 12/41 years of data
# Skipping PACD, due to only have 33/41 years of data
# Skipping PACE, due to only have 3/41 years of data
# Skipping GUC, due to only have 21/41 years of data
# Skipping GUS, due to only have 28/41 years of data
# GUP 0.0 0
# Skipping DLF, due to only have 33/41 years of data
# HUF 100.0 42
# Skipping HUL, due to only have 34/41 years of data
# Skipping HUM, due to only have 4/41 years of data
# Skipping HUT, due to only have 18/41 years of data
# Skipping AFF, due to only have 7/41 years of data
# Skipping NFG, due to only have 6/41 years of data
# BLU 11.9047619048 5
# Skipping NFL, due to only have 18/41 years of data
# Skipping BLM, due to only have 19/41 years of data
# BLI 16.6666666667 7
# Skipping BLH, due to only have 32/41 years of data
# Skipping BLF, due to only have 35/41 years of data
# Skipping LZK, due to only have 2/41 years of data
# EKO 7.14285714286 3
# EKN 52.380952381 22
# Skipping EKA, due to only have 0/41 years of data
# Skipping REO, due to only have 24/41 years of data
# MKC 80.9523809524 34
# Skipping FCS, due to only have 7/41 years of data
# LFI 50.0 21
# Skipping LFK, due to only have 36/41 years of data
# LFT 21.4285714286 9
# FCH 0.0 0
# FCI 69.0476190476 29
# Skipping LTS, due to only have 33/41 years of data
# FMY 0.0 0
# Skipping O87, due to only have 0/41 years of data
# FMN 0.0 0
# Skipping PAEH, due to only have 12/41 years of data
# Skipping FMH, due to only have 27/41 years of data
# Skipping VEL, due to only have 16/41 years of data
# Skipping FME, due to only have 6/41 years of data
# Skipping 4SL, due to only have 0/41 years of data
# CAR 30.9523809524 13
# CAK 71.4285714286 30
# Skipping CAO, due to only have 35/41 years of data
# CAE 30.9523809524 13
# Skipping CAD, due to only have 18/41 years of data
# Skipping PGA, due to only have 30/41 years of data
# Skipping DYR, due to only have 20/41 years of data
# Skipping DYS, due to only have 24/41 years of data
# Skipping MBL, due to only have 20/41 years of data
# Skipping WRI, due to only have 32/41 years of data
# RSL 47.619047619 20
# RST 126.19047619 53
# Skipping OGD, due to only have 15/41 years of data
# JFK 30.9523809524 13
# MIA 0.0 0
# Skipping MIB, due to only have 34/41 years of data
# Skipping MIE, due to only have 14/41 years of data
# Skipping DKK, due to only have 16/41 years of data
# MIV 26.1904761905 11
# Skipping PABT, due to only have 36/41 years of data
# Skipping PABR, due to only have 35/41 years of data
# AOO 66.6666666667 28
# NQX 9.52380952381 4
# PABE 80.9523809524 34
# Skipping NQA, due to only have 32/41 years of data
# Skipping PABA, due to only have 16/41 years of data
# Skipping PABI, due to only have 33/41 years of data
# Skipping PALU, due to only have 11/41 years of data
# Skipping PALK, due to only have 0/41 years of data
# Skipping PALJ, due to only have 0/41 years of data
# Skipping IPL, due to only have 33/41 years of data
# SFO 4.7619047619 2
# Skipping PHSF, due to only have 1/41 years of data
# IPT 19.0476190476 8
# SFF 11.9047619048 5
# Skipping SFB, due to only have 21/41 years of data
# Skipping PAPM, due to only have 8/41 years of data
# Skipping PAPO, due to only have 8/41 years of data
# Skipping PAPH, due to only have 19/41 years of data
# Skipping PAPG, due to only have 17/41 years of data
# NGU 21.4285714286 9
# Skipping HDE, due to only have 11/41 years of data
# Skipping HDN, due to only have 20/41 years of data
# Skipping PAPR, due to only have 31/41 years of data
# Skipping BMG, due to only have 12/41 years of data
# Skipping SZL, due to only have 35/41 years of data
# Skipping BML, due to only have 18/41 years of data
# Skipping 4HV, due to only have 0/41 years of data
# SHR 23.8095238095 10
# SHV 50.0 21
# Skipping SHD, due to only have 19/41 years of data
# Skipping SHN, due to only have 15/41 years of data
# Skipping MGE, due to only have 17/41 years of data
# MGM 57.1428571429 24
# Skipping MGR, due to only have 11/41 years of data
# MGW 69.0476190476 29
# Skipping TBN, due to only have 8/41 years of data
# Skipping LUF, due to only have 31/41 years of data
# LUK 47.619047619 20
# Skipping GTB, due to only have 24/41 years of data
# GTF 38.0952380952 16
# Skipping RME, due to only have 28/41 years of data
# FTW 52.380952381 22
# TLH 23.8095238095 10
# Skipping GCN, due to only have 16/41 years of data
# Skipping HVN, due to only have 13/41 years of data
# Skipping YKN, due to only have 21/41 years of data
# HVR 23.8095238095 10
# Skipping CMX, due to only have 30/41 years of data
# YKM 16.6666666667 7
# RPX 45.2380952381 19
# Skipping UCY, due to only have 18/41 years of data
# Skipping UCA, due to only have 24/41 years of data
# Skipping RBL, due to only have 35/41 years of data
# Skipping RBG, due to only have 16/41 years of data
# OTM 64.2857142857 27
# Skipping LGB, due to only have 30/41 years of data
# LGA 54.7619047619 23
# Skipping LGD, due to only have 20/41 years of data
# Skipping OTG, due to only have 19/41 years of data
# Skipping 4BL, due to only have 0/41 years of data
# GSP 59.5238095238 25
# AXN 47.619047619 20
# Skipping IWD, due to only have 17/41 years of data
# Skipping IWA, due to only have 15/41 years of data
# PHTO 0.0 0
# BOS 66.6666666667 28
# Skipping OFF, due to only have 36/41 years of data
# IAH 11.9047619048 5
# IAD 21.4285714286 9
# IAB 57.1428571429 24
# Skipping BOW, due to only have 5/41 years of data
# PHL 35.7142857143 15
# Skipping PHG, due to only have 12/41 years of data
# PHF 33.3333333333 14
# Skipping PHP, due to only have 15/41 years of data
# Skipping SKF, due to only have 35/41 years of data
# SKA 30.9523809524 13
# MFD 85.7142857143 36
# TCS 23.8095238095 10
# MFR 2.38095238095 1
# TCM 16.6666666667 7
# GEG 11.9047619048 5
# Skipping TCC, due to only have 23/41 years of data
# Skipping MHK, due to only have 16/41 years of data
# Skipping MHE, due to only have 21/41 years of data
# DDC 64.2857142857 27
# Skipping MHT, due to only have 19/41 years of data
# Skipping MHR, due to only have 23/41 years of data
# Skipping MHS, due to only have 35/41 years of data
# ADW 35.7142857143 15
# Skipping AND, due to only have 30/41 years of data
# Skipping PAAQ, due to only have 16/41 years of data
# ANB 19.0476190476 8
# ANJ 57.1428571429 24
# Skipping ANW, due to only have 17/41 years of data
# Skipping PAAK, due to only have 8/41 years of data
# GWO 116.666666667 49
# Skipping NJK, due to only have 8/41 years of data
# Skipping HWD, due to only have 15/41 years of data
# Skipping PAWI, due to only have 10/41 years of data
# Skipping HEQ, due to only have 12/41 years of data
# Skipping PAWD, due to only have 14/41 years of data
# Skipping HEZ, due to only have 22/41 years of data
# Skipping PAWG, due to only have 21/41 years of data
# Skipping XMR, due to only have 12/41 years of data
# Skipping PPIZ, due to only have 6/41 years of data
# Skipping PHHN, due to only have 0/41 years of data
# Skipping PHHI, due to only have 8/41 years of data
# Skipping HYA, due to only have 17/41 years of data
# Skipping HYI, due to only have 18/41 years of data
# Skipping RCA, due to only have 36/41 years of data
# Skipping FAY, due to only have 29/41 years of data
# FAR 138.095238095 58
# Skipping OWD, due to only have 15/41 years of data
# FAT 0.0 0
# Skipping OWB, due to only have 8/41 years of data
# Skipping FAF, due to only have 7/41 years of data
# Skipping LVS, due to only have 23/41 years of data
# Skipping SVC, due to only have 14/41 years of data
# Skipping LVM, due to only have 18/41 years of data
# Skipping LVK, due to only have 15/41 years of data
# POU 47.619047619 20
# OAK 0.0 0
# Skipping CCR, due to only have 14/41 years of data
# PIH 16.6666666667 7
# Skipping PIL, due to only have 15/41 years of data
# MYR 38.0952380952 16
# Skipping MYV, due to only have 23/41 years of data
# PIR 28.5714285714 12
# PIT 102.380952381 43
# Skipping MYF, due to only have 16/41 years of data
# WMC 0.0 0
# Skipping MWS, due to only have 4/41 years of data
# GJT 4.7619047619 2
# DET 73.8095238095 31
# SMF 0.0 0
# Skipping MWN, due to only have 18/41 years of data
# Skipping MWL, due to only have 15/41 years of data
# AMA 30.9523809524 13
# Skipping AMG, due to only have 14/41 years of data
# Skipping 87Q, due to only have 17/41 years of data
# Skipping ACB, due to only have 23/41 years of data
# Skipping NEL, due to only have 3/41 years of data
# ACV 7.14285714286 3
# ACT 38.0952380952 16
# Skipping NEW, due to only have 33/41 years of data
# ACY 21.4285714286 9
# Skipping PAVW, due to only have 26/41 years of data
# Skipping BKE, due to only have 33/41 years of data
# BKF 59.5238095238 25
# Skipping BKL, due to only have 16/41 years of data
# PHIK 0.0 0
# Skipping GGG, due to only have 29/41 years of data
# BKW 104.761904762 44
# Skipping COT, due to only have 27/41 years of data
# Skipping BKX, due to only have 19/41 years of data
# OTH 9.52380952381 4
# SJT 38.0952380952 16
# Skipping SJC, due to only have 24/41 years of data
# Skipping GDP, due to only have 32/41 years of data
# Skipping GDV, due to only have 20/41 years of data
# Skipping MEB, due to only have 15/41 years of data
# MEM 97.619047619 41
# MEI 28.5714285714 12
# Skipping MEH, due to only have 36/41 years of data
# Skipping PSC, due to only have 16/41 years of data
# Skipping LWS, due to only have 33/41 years of data
# YNG 173.80952381 73
# Skipping LWT, due to only have 33/41 years of data
# Skipping LWB, due to only have 14/41 years of data
# Skipping LWD, due to only have 16/41 years of data
# TXK 40.4761904762 17
# Skipping HHR, due to only have 15/41 years of data
# NKT 7.14285714286 3
# Skipping NKX, due to only have 20/41 years of data
# ROC 109.523809524 46
# AUW 47.619047619 20
# CPR 21.4285714286 9
# Skipping CPW, due to only have 9/41 years of data
# WRB 33.3333333333 14
# Skipping WRL, due to only have 31/41 years of data
# Skipping LAL, due to only have 3/41 years of data
# LAN 76.1904761905 32
# LAF 76.1904761905 32
# FFO 109.523809524 46
# LAX 2.38095238095 1
# Skipping LAR, due to only have 33/41 years of data
# LAS 0.0 0
# Skipping PAGS, due to only have 20/41 years of data
# NTU 11.9047619048 5
# Skipping UOX, due to only have 5/41 years of data
# DTW 69.0476190476 29
# Skipping SBA, due to only have 35/41 years of data
# BDL 42.8571428571 18
# Skipping FTY, due to only have 35/41 years of data
# Skipping U24, due to only have 0/41 years of data
# ALW 33.3333333333 14
# Skipping FTK, due to only have 32/41 years of data
# Skipping U28, due to only have 0/41 years of data
# Skipping CBK, due to only have 32/41 years of data
# Skipping CBM, due to only have 12/41 years of data
# Skipping MXF, due to only have 17/41 years of data
# Skipping SMX, due to only have 32/41 years of data
# Skipping SMP, due to only have 28/41 years of data
# Skipping SMO, due to only have 14/41 years of data
# Skipping SMN, due to only have 21/41 years of data
# BZN 2.38095238095 1
# GGW 23.8095238095 10
# Skipping JST, due to only have 22/41 years of data
# Skipping MDT, due to only have 34/41 years of data
# Skipping MVY, due to only have 16/41 years of data
# Skipping MQY, due to only have 8/41 years of data
# Skipping JEF, due to only have 16/41 years of data
# Skipping LRD, due to only have 34/41 years of data
# ALO 88.0952380952 37
# Skipping ALI, due to only have 29/41 years of data
# ALB 38.0952380952 16
# PAGK 7.14285714286 3
# Skipping PAGM, due to only have 12/41 years of data
# Skipping PAGA, due to only have 32/41 years of data
# Skipping ALS, due to only have 33/41 years of data
# Skipping HTL, due to only have 33/41 years of data
# TOP 66.6666666667 28
# Skipping TOI, due to only have 8/41 years of data
# TOL 90.4761904762 38
# Skipping TOA, due to only have 0/41 years of data
# NHK 11.9047619048 5
# ERI 107.142857143 45
# Skipping HIB, due to only have 22/41 years of data
# HIF 4.7619047619 2
# OFK 71.4285714286 30
# Skipping HII, due to only have 15/41 years of data
# IAG 71.4285714286 30
# HIO 0.0 0
# ABE 33.3333333333 14
# ABI 33.3333333333 14
# NZY 0.0 0
# Skipping HGR, due to only have 15/41 years of data
# ABQ 0.0 0
# Skipping ABR, due to only have 36/41 years of data
# Skipping PAUN, due to only have 22/41 years of data
# BHM 52.380952381 22
# Skipping PHJR, due to only have 34/41 years of data
# Skipping EGI, due to only have 5/41 years of data
# Skipping EGE, due to only have 33/41 years of data
# Skipping OQU, due to only have 0/41 years of data
# Skipping LBT, due to only have 14/41 years of data
# LBB 26.1904761905 11
# Skipping LBE, due to only have 0/41 years of data
# RAP 33.3333333333 14
# LBF 28.5714285714 12
# Skipping LBL, due to only have 20/41 years of data
# BFF 47.619047619 20
# BFI 4.7619047619 2
# Skipping BFM, due to only have 7/41 years of data
# BFL 0.0 0
# EYW 2.38095238095 1
# Skipping VIH, due to only have 25/41 years of data
# Skipping VIS, due to only have 18/41 years of data
# Skipping NHZ, due to only have 35/41 years of data
# Skipping TYR, due to only have 24/41 years of data
# TYS 57.1428571429 24
# Skipping OCF, due to only have 20/41 years of data
# Skipping FUL, due to only have 15/41 years of data
# Skipping CEF, due to only have 18/41 years of data
# Skipping CEC, due to only have 4/41 years of data
# Skipping CEW, due to only have 31/41 years of data
# Skipping CEZ, due to only have 17/41 years of data
# CEY 71.4285714286 30
# Skipping CSM, due to only have 17/41 years of data
# CSG 33.3333333333 14
# CSV 119.047619048 50
# Skipping JBR, due to only have 33/41 years of data
# DMA 0.0 0
# Skipping NZJ, due to only have 12/41 years of data
# Skipping MUO, due to only have 34/41 years of data
# AST 7.14285714286 3
# NUQ 0.0 0
# Skipping PAFK, due to only have 0/41 years of data
# Skipping GBN, due to only have 0/41 years of data
# Skipping ASE, due to only have 15/41 years of data
# PAFA 64.2857142857 27
# Skipping NUC, due to only have 11/41 years of data
# Skipping PAFE, due to only have 17/41 years of data
# DUJ 126.19047619 53
# Skipping DUG, due to only have 34/41 years of data
# Skipping UNO, due to only have 17/41 years of data
# OMA 47.619047619 20
# Skipping ITH, due to only have 9/41 years of data
# Skipping OMH, due to only have 22/41 years of data
# RDU 54.7619047619 23
# Skipping AAF, due to only have 24/41 years of data
# Skipping PATA, due to only have 14/41 years of data
# Skipping PATC, due to only have 11/41 years of data
# Skipping PATK, due to only have 24/41 years of data
# Skipping PATL, due to only have 11/41 years of data
# Skipping PHKO, due to only have 16/41 years of data
# Skipping BIH, due to only have 29/41 years of data
# Skipping BID, due to only have 24/41 years of data
# Skipping BIX, due to only have 36/41 years of data
# BIS 45.2380952381 19
# SLN 59.5238095238 25
# Skipping SLO, due to only have 13/41 years of data
# Skipping SLI, due to only have 6/41 years of data
# NCA 9.52380952381 4
# SLE 9.52380952381 4
# Skipping MFE, due to only have 36/41 years of data
# MCO 2.38095238095 1
# MCN 11.9047619048 5
# Skipping MCK, due to only have 13/41 years of data
# Skipping MCF, due to only have 35/41 years of data
# Skipping MCC, due to only have 25/41 years of data
# GFK 71.4285714286 30
# GFL 11.9047619048 5
# MCW 73.8095238095 31
# Skipping GFA, due to only have 30/41 years of data
# BGM 100.0 42
# BGR 23.8095238095 10
# TCL 52.380952381 22
# Skipping VNY, due to only have 23/41 years of data
# Skipping W99, due to only have 11/41 years of data
# Skipping GPT, due to only have 16/41 years of data
# Skipping NID, due to only have 8/41 years of data
# CRP 23.8095238095 10
# Skipping CRQ, due to only have 19/41 years of data
# CRW 92.8571428571 39
# Skipping CRE, due to only have 14/41 years of data
# FDY 97.619047619 41
# Skipping PQL, due to only have 13/41 years of data
# OZR 11.9047619048 5
# Skipping OSC, due to only have 35/41 years of data
# Skipping EFD, due to only have 30/41 years of data
# RNO 0.0 0
# Skipping RNM, due to only have 15/41 years of data
# Skipping RND, due to only have 35/41 years of data
# Skipping OPF, due to only have 15/41 years of data
# LCH 47.619047619 20
# Skipping LCI, due to only have 20/41 years of data
# Skipping DVL, due to only have 20/41 years of data
# OLD 21.4285714286 9
# Skipping OLF, due to only have 15/41 years of data
# Skipping AZO, due to only have 22/41 years of data
# OLM 14.2857142857 6
# Skipping OLU, due to only have 20/41 years of data
# MSN 95.2380952381 40
# Skipping CDR, due to only have 21/41 years of data
# Skipping CDS, due to only have 33/41 years of data
# Skipping PLN, due to only have 36/41 years of data
# PAED 42.8571428571 18
# PAEN 16.6666666667 7
# Skipping IYK, due to only have 0/41 years of data
# Skipping PAEI, due to only have 33/41 years of data
# Skipping PPA, due to only have 11/41 years of data
# Skipping BFD, due to only have 34/41 years of data
# Skipping GAO, due to only have 8/41 years of data
# Skipping GAG, due to only have 34/41 years of data
# Skipping GAD, due to only have 9/41 years of data
# MBS 52.380952381 22
# Skipping JCT, due to only have 35/41 years of data
# Skipping MTW, due to only have 19/41 years of data
# Skipping MTJ, due to only have 18/41 years of data
# Skipping MTN, due to only have 8/41 years of data
# MTC 73.8095238095 31
# Skipping DAA, due to only have 33/41 years of data
# ART 95.2380952381 40
# Skipping ARA, due to only have 8/41 years of data
# Skipping ARG, due to only have 21/41 years of data
# Skipping TIW, due to only have 15/41 years of data
# Skipping GSB, due to only have 35/41 years of data
# Skipping TIK, due to only have 13/41 years of data
# Skipping GSH, due to only have 17/41 years of data
# Skipping Y22, due to only have 12/41 years of data
# GSO 52.380952381 22
# Skipping HKY, due to only have 36/41 years of data
# Skipping HKS, due to only have 14/41 years of data
# Skipping PAGY, due to only have 17/41 years of data
# Skipping 4CR, due to only have 0/41 years of data
# PHLI 0.0 0
# Skipping BVE, due to only have 13/41 years of data
# Skipping BVO, due to only have 14/41 years of data
# Skipping EEN, due to only have 21/41 years of data
# Skipping EED, due to only have 18/41 years of data
# ROA 26.1904761905 11
# Skipping OSU, due to only have 16/41 years of data
# Skipping OSH, due to only have 17/41 years of data
# Skipping ROW, due to only have 36/41 years of data
# Skipping EWN, due to only have 36/41 years of data
# Skipping EWB, due to only have 17/41 years of data
# Skipping BDR, due to only have 25/41 years of data
# EWR 21.4285714286 9
# Skipping VTN, due to only have 35/41 years of data
# Skipping LRF, due to only have 35/41 years of data
# Skipping VOK, due to only have 7/41 years of data
# Skipping LRU, due to only have 14/41 years of data
# Skipping IDL, due to only have 9/41 years of data
# Skipping IDA, due to only have 36/41 years of data
# Skipping TVL, due to only have 14/41 years of data
# ZZV 80.9523809524 34
# Skipping CGF, due to only have 0/41 years of data
# Skipping PMD, due to only have 16/41 years of data
# Skipping CIC, due to only have 4/41 years of data
# MSY 30.9523809524 13
# CID 102.380952381 43
# MSS 85.7142857143 36
# MSP 64.2857142857 27
# MSO 16.6666666667 7
# MSL 47.619047619 20
# Skipping AQW, due to only have 16/41 years of data
# Skipping DAG, due to only have 33/41 years of data
# DAB 2.38095238095 1
# DAL 38.0952380952 16
# Skipping DAN, due to only have 19/41 years of data
# DAY 59.5238095238 25
# Skipping 3A1, due to only have 12/41 years of data
# Skipping 3A6, due to only have 2/41 years of data

# %%
df = pd.DataFrame(rows)
import numpy as np

from pyiem.plot import MapPlot

df2 = df[df.sid != "BNW"]

m = MapPlot(
    sector="conus",
    title="Total Number of Days Without At Least One Rise in Hourly Temperature",
    subtitle="based on automated stations hourly METARs, number of events (days) plotted for period 1973-2014",
)
m.contourf(
    np.array(df2.lon),
    np.array(df2.lat),
    np.array(df2.val),
    np.arange(0, 101, 5),
    units="days",
)
# m.plot_values(df2.lon, df2.lat, df2.val, fmt='%.0f')
m.postprocess(filename="test.png")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 df = pd.DataFrame(rows)
#       2 import numpy as np
#       4 from pyiem.plot import MapPlot
#
# NameError: name 'pd' is not defined
